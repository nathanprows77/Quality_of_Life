# %% [markdown]
# ## Data Cleaning - For Tableau Import/Map
#
# ### Import dependcies and read in csv files

# %%
# Import pandas

import pandas as pd

# %%
# Assigning the paths to our CSV files

# file = "../Resources/Pollution_clean/Clean_Pollution.csv"
file1 = "../Resources/Medicare_clean/clean_pc_state_rates_2011.csv"
file2 = "../Resources/Medicare_clean/clean_pc_state_rates_2012.csv"
file3 = "../Resources/Medicare_clean/clean_pc_state_rates_2013.csv"
file4 = "../Resources/Medicare_clean/clean_pc_state_rates_2014.csv"
file5 = "../Resources/Medicare_clean/clean_pc_state_rates_2015.csv"
file6 = "../Resources/Census_clean/clean_census_2011.csv"
file7 = "../Resources/Census_clean/clean_census_2012.csv"
file8 = "../Resources/Census_clean/clean_census_2013.csv"
file9 = "../Resources/Census_clean/clean_census_2014.csv"
file10 = "../Resources/Census_clean/clean_census_2015.csv"
file11 = "../Resources/Tableau_clean/states_lat_and_long.csv"
file12 = "../Resources/Tableau_clean/Pollution_2011.csv"
file13 = "../Resources/Tableau_clean/Pollution_2012.csv"
file14 = "../Resources/Tableau_clean/Pollution_2013.csv"
file15 = "../Resources/Tableau_clean/Pollution_2014.csv"
file16 = "../Resources/Tableau_clean/Pollution_2015.csv"

# %%
# Latitude and longitude: from https://developers.google.com/public-data/docs/canonical/states_csv

states = pd.read_csv(file11)
states = states.sort_values("name") 
states
# Out:
#    state   latitude   longitude                  name
# 1     AL  32.318231  -86.902298               Alabama
# 0     AK  63.588753 -154.493062                Alaska
# 3     AZ  34.048928 -111.093731               Arizona
# 2     AR  35.201050  -91.831833              Arkansas
# 4     CA  36.778261 -119.417932            California
# 5     CO  39.550051 -105.782067              Colorado
# 6     CT  41.603221  -73.087749           Connecticut
# 8     DE  38.910832  -75.527670              Delaware
# 7     DC  38.905985  -77.033418  District of Columbia
# 9     FL  27.664827  -81.515754               Florida
# 10    GA  32.157435  -82.907123               Georgia
# 11    HI  19.898682 -155.665857                Hawaii
# 13    ID  44.068202 -114.742041                 Idaho
# 14    IL  40.633125  -89.398528              Illinois
# 15    IN  40.551217  -85.602364               Indiana
# 12    IA  41.878003  -93.097702                  Iowa
# ...

# %% [markdown]
# ### Medicare Data

# %%
# Read our data into pandas

medicare_2011 = pd.read_csv(file1)
medicare_2012 = pd.read_csv(file2)
medicare_2013 = pd.read_csv(file3)
medicare_2014 = pd.read_csv(file4)
medicare_2015 = pd.read_csv(file5)

# %%
medicare_2011.head()
# Out:
#    state_id  state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 0         1     Alabama                478784                  82.5
# 1         2      Alaska                 49648                  70.9
# 2         3     Arizona                465298                  78.2
# 3         4    Arkansas                327939                  80.7
# 4         5  California               2238140                  72.7
#
#    diabetic_enrollees_age_65_to_75  \
# 0                            69691
# 1                             5449
# 2                            50991
# 3                            40202
# 4                           243999
#
#    average_diabetic_enrollees_hemoglobin_a1c_test  \
# 0                                            83.9
# 1                                            74.5
# 2                                            78.5
# 3                                            82.5
# 4                                            80.6
#
# ...

# %%
# Idenitfy nan values from 2013

medicare_2013.tail()
# Out:
#     state_id state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 52       NaN        NaN                   NaN                   NaN
# 53       NaN        NaN                   NaN                   NaN
# 54       NaN        NaN                   NaN                   NaN
# 55       NaN        NaN                   NaN                   NaN
# 56       NaN        NaN                   NaN                   NaN
#
#     diabetic_enrollees_age_65_to_75  \
# 52                              NaN
# 53                              NaN
# 54                              NaN
# 55                              NaN
# 56                              NaN
#
#     average_diabetic_enrollees_hemoglobin_a1c_test  \
# 52                                             NaN
# 53                                             NaN
# 54                                             NaN
# 55                                             NaN
# 56                                             NaN
#
# ...

# %%
# Drop nan values from 2013

medicare_2013_dropped = medicare_2013.iloc[0:52]
medicare_2013_dropped.tail()
# Out:
#     state_id     state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 47      50.0     Washington              571799.0                  78.9
# 48      51.0  West Virginia              204275.0                  80.9
# 49      52.0      Wisconsin              484902.0                  80.1
# 50      53.0        Wyoming               68066.0                  74.6
# 51      99.0  United States            26755951.0                  79.1
#
#     diabetic_enrollees_age_65_to_75  \
# 47                          61248.0
# 48                          32596.0
# 49                          52893.0
# 50                           6475.0
# 51                        3313579.0
#
#     average_diabetic_enrollees_hemoglobin_a1c_test  \
# 47                                            86.1
# 48                                            83.8
# 49                                            90.0
# 50                                            75.4
# ...

# %%
# Drop extra row tallying up the United States

medicare_2011_states = medicare_2011.iloc[0:51]
medicare_2012_states = medicare_2012.iloc[0:51]
medicare_2013_states = medicare_2013_dropped.iloc[0:51]
medicare_2014_states = medicare_2014.iloc[0:51]
medicare_2015_states = medicare_2015.iloc[0:51]
medicare_2013_states.tail()
# Out:
#     state_id     state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 46      49.0       Virginia              807461.0                  82.7
# 47      50.0     Washington              571799.0                  78.9
# 48      51.0  West Virginia              204275.0                  80.9
# 49      52.0      Wisconsin              484902.0                  80.1
# 50      53.0        Wyoming               68066.0                  74.6
#
#     diabetic_enrollees_age_65_to_75  \
# 46                         107366.0
# 47                          61248.0
# 48                          32596.0
# 49                          52893.0
# 50                           6475.0
#
#     average_diabetic_enrollees_hemoglobin_a1c_test  \
# 46                                            86.6
# 47                                            86.1
# 48                                            83.8
# 49                                            90.0
# ...

# %%
# Sort Medicare dataframes by state name

medicare_2011 = medicare_2011.sort_values("state_name")  
medicare_2012 = medicare_2012.sort_values("state_name")  
medicare_2013 = medicare_2013.sort_values("state_name")  
medicare_2014 = medicare_2014.sort_values("state_name")  
medicare_2015 = medicare_2015.sort_values("state_name")

# %%
# Append latitude and longitude into Medicare dataframes

medicare_2011['latitude'] = states['latitude']
medicare_2011['longitude'] = states['longitude']
medicare_2012['latitude'] = states['latitude']
medicare_2012['longitude'] = states['longitude']
medicare_2013['latitude'] = states['latitude']
medicare_2013['longitude'] = states['longitude']
medicare_2014['latitude'] = states['latitude']
medicare_2014['longitude'] = states['longitude']
medicare_2015['latitude'] = states['latitude']
medicare_2015['longitude'] = states['longitude']

# %%
medicare_2015
# Out:
#     state_id            state_name  beneficiaries_part_b  \
# 0          1               Alabama                510586
# 1          2                Alaska                 61807
# 2          3               Arizona                549896
# 3          4              Arkansas                340105
# 4          5            California               2334245
# 5          6              Colorado                362323
# 6          7           Connecticut                344478
# 7          8              Delaware                129807
# 8          9  District of Columbia                 48159
# 9         10               Florida               1861794
# 10        11               Georgia                748200
# 11        12                Hawaii                 91929
# 12        13                 Idaho                141812
# 13        14              Illinois               1210320
# 14        15               Indiana                646310
# ...

# %%
# Lists for year columns (made in excel using the "&" formula and the fill function)

medicare_year_2011 = ["2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011"]

medicare_year_2012 = ["2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012"]

medicare_year_2013 = ["2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013"]

medicare_year_2014 = ["2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014"]

medicare_year_2015 = ["2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015"]

# %%
# Adding the year column into each dataframe in order to use year filters in Tableau

medicare_2011_states.insert(1, "year", medicare_year_2011, True)
medicare_2012_states.insert(1, "year", medicare_year_2012, True)
medicare_2013_states.insert(1, "year", medicare_year_2013, True)
medicare_2014_states.insert(1, "year", medicare_year_2014, True)
medicare_2015_states.insert(1, "year", medicare_year_2015, True)

# %%
# Stack tables together using concat

medicare_concat_1 = pd.concat([medicare_2011_states, medicare_2012_states], axis =0)
medicare_concat_2 = pd.concat([medicare_concat_1, medicare_2013_states], axis =0)
medicare_concat_3 = pd.concat([medicare_concat_2, medicare_2014_states], axis =0)
medicare_all = pd.concat([medicare_concat_3, medicare_2015_states], axis =0)
medicare_all
# Out:
#     state_id  year     state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 0        1.0  2011        Alabama              478784.0                  82.5
# 1        2.0  2011         Alaska               49648.0                  70.9
# 2        3.0  2011        Arizona              465298.0                  78.2
# 3        4.0  2011       Arkansas              327939.0                  80.7
# 4        5.0  2011     California             2238140.0                  72.7
# ..       ...   ...            ...                   ...                   ...
# 46      49.0  2015       Virginia              832699.0                  83.3
# 47      50.0  2015     Washington              610922.0                  78.5
# 48      51.0  2015  West Virginia              206961.0                  80.8
# 49      52.0  2015      Wisconsin              474364.0                  79.8
# 50      53.0  2015        Wyoming               72959.0                  72.7
#
# ...

# %%
# Export to csv

medicare_all.to_csv('../Resources\Tableau_clean\medicare_all.csv', index=False)

# %% [markdown]
# ### Census Data

# %%
# Read our data into pandas

census_2011 = pd.read_csv(file6)
census_2012 = pd.read_csv(file7)
census_2013 = pd.read_csv(file8)
census_2014 = pd.read_csv(file9)
census_2015 = pd.read_csv(file10)

# %%
census_2011
# Out:
#                     Name  Population    HHI  PovertyRate
# 0                Alabama     4747424  42934    17.133186
# 1                 Alaska      700703  69014     9.292239
# 2                Arizona     6337373  50752    15.835820
# 3               Arkansas     2895928  40149    17.846507
# 4             California    36969200  61632    14.096818
# 5               Colorado     4966061  57685    12.237606
# 6            Connecticut     3558172  69243     9.183676
# 7               Delaware      890856  59317    10.866515
# 8   District of Columbia      593955  61835    17.144902
# 9                Florida    18688787  47827    14.336939
# 10               Georgia     9600612  49736    16.055872
# 11                Hawaii     1346554  67116     9.980068
# 12                 Idaho     1549987  46890    13.982956
# 13              Illinois    12790182  56576    12.825681
# 14               Indiana     6454254  48393    13.714211
# ...

# %%
# Drop extra row tallying up Puerto Rico

census_2011_states = census_2011.iloc[0:51]
census_2012_states = census_2012.iloc[0:51]
census_2013_states = census_2013.iloc[0:51]
census_2014_states = census_2014.iloc[0:51]
census_2015_states = census_2015.iloc[0:51]
census_2011_states
# Out:
#                     Name  Population    HHI  PovertyRate
# 0                Alabama     4747424  42934    17.133186
# 1                 Alaska      700703  69014     9.292239
# 2                Arizona     6337373  50752    15.835820
# 3               Arkansas     2895928  40149    17.846507
# 4             California    36969200  61632    14.096818
# 5               Colorado     4966061  57685    12.237606
# 6            Connecticut     3558172  69243     9.183676
# 7               Delaware      890856  59317    10.866515
# 8   District of Columbia      593955  61835    17.144902
# 9                Florida    18688787  47827    14.336939
# 10               Georgia     9600612  49736    16.055872
# 11                Hawaii     1346554  67116     9.980068
# 12                 Idaho     1549987  46890    13.982956
# 13              Illinois    12790182  56576    12.825681
# 14               Indiana     6454254  48393    13.714211
# ...

# %%
# Sort Census dataframes by state name

census_2011 = census_2011.sort_values("Name")  
census_2012 = census_2012.sort_values("Name")  
census_2013 = census_2013.sort_values("Name")  
census_2014 = census_2014.sort_values("Name")  
census_2015 = census_2015.sort_values("Name")

# %%
# Append latitude and longitude into Census dataframes

census_2011['Latitude'] = states['latitude']
census_2011['Longitude'] = states['longitude']
census_2012['Latitude'] = states['latitude']
census_2012['Longitude'] = states['longitude']
census_2013['Latitude'] = states['latitude']
census_2013['Longitude'] = states['longitude']
census_2014['Latitude'] = states['latitude']
census_2014['Longitude'] = states['longitude']
census_2015['Latitude'] = states['latitude']
census_2015['Longitude'] = states['longitude']

# %%
census_2011
# Out:
#                     Name  Population    HHI  PovertyRate   Latitude  \
# 0                Alabama     4747424  42934    17.133186  63.588753
# 1                 Alaska      700703  69014     9.292239  32.318231
# 2                Arizona     6337373  50752    15.835820  35.201050
# 3               Arkansas     2895928  40149    17.846507  34.048928
# 4             California    36969200  61632    14.096818  36.778261
# 5               Colorado     4966061  57685    12.237606  39.550051
# 6            Connecticut     3558172  69243     9.183676  41.603221
# 7               Delaware      890856  59317    10.866515  38.905985
# 8   District of Columbia      593955  61835    17.144902  38.910832
# 9                Florida    18688787  47827    14.336939  27.664827
# 10               Georgia     9600612  49736    16.055872  32.157435
# 11                Hawaii     1346554  67116     9.980068  19.898682
# 12                 Idaho     1549987  46890    13.982956  41.878003
# ...

# %%
# Lists for year columns (copied from above)

census_year_2011 = ["2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011"]

census_year_2012 = ["2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012"]

census_year_2013 = ["2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013"]

census_year_2014 = ["2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014"]

census_year_2015 = ["2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015"]

# %%
# Adding the year column into each dataframe

census_2011_states.insert(1, "year", census_year_2011, True)
census_2012_states.insert(1, "year", census_year_2012, True)
census_2013_states.insert(1, "year", census_year_2013, True)
census_2014_states.insert(1, "year", census_year_2014, True)
census_2015_states.insert(1, "year", census_year_2015, True)

# %%
# Stack tables together using concat

census_concat_1 = pd.concat([census_2011_states, census_2012_states], axis =0)
census_concat_2 = pd.concat([census_concat_1, census_2013_states], axis =0)
census_concat_3 = pd.concat([census_concat_2, census_2014_states], axis =0)
census_all = pd.concat([census_concat_3, census_2015_states], axis =0)
census_all
# Out:
#              Name  year  Population    HHI  PovertyRate
# 0         Alabama  2011     4747424  42934    17.133186
# 1          Alaska  2011      700703  69014     9.292239
# 2         Arizona  2011     6337373  50752    15.835820
# 3        Arkansas  2011     2895928  40149    17.846507
# 4      California  2011    36969200  61632    14.096818
# ..            ...   ...         ...    ...          ...
# 46       Virginia  2015     8256630  65015    11.164628
# 47     Washington  2015     6985464  61062    13.005750
# 48  West Virginia  2015     1851420  41751    17.466809
# 49      Wisconsin  2015     5742117  53357    12.614651
# 50        Wyoming  2015      579679  58840    11.212240
#
# [255 rows x 5 columns]

# %%
# Export to csv

census_all.to_csv('..\Resources\Tableau_clean\census_all.csv', index=False)

# %% [markdown]
# ### Pollution Data

# %%
# Read our data into pandas

pollution_2011 = pd.read_csv(file12)
pollution_2012 = pd.read_csv(file13)
pollution_2013 = pd.read_csv(file14)
pollution_2014 = pd.read_csv(file15)
pollution_2015 = pd.read_csv(file16)

# %%
# Sort Pollution dataframes by state name

pollution_2011 = pollution_2011.sort_values("State")  
pollution_2012 = pollution_2012.sort_values("State")  
pollution_2013 = pollution_2013.sort_values("State")  
pollution_2014 = pollution_2014.sort_values("State")  
pollution_2015 = pollution_2015.sort_values("State")

# %%
# Sort Pollution dataframes by state name

pollution_2011_states = pollution_2011.sort_values("State")  
pollution_2012_states = pollution_2012.sort_values("State")  
pollution_2013_states = pollution_2013.sort_values("State")  
pollution_2014_states = pollution_2014.sort_values("State")  
pollution_2015_states = pollution_2015.sort_values("State")

# %%
pollution_2011_states.head()
# Out:
#      State   County  Year  Days_with_AQI  Good_Days  Moderate_Days  \
# 0  Alabama  Baldwin  2011            282        204             69
# 9  Alabama  Madison  2011            331        222            105
# 1  Alabama     Clay  2011            118         80             38
# 2  Alabama  Colbert  2011            279        214             64
# 3  Alabama   DeKalb  2011            336        257             78
#
#    Unhealthy_Days  Very_Unhealthy_Days  Hazardous_Days  Max_AQI  Median_AQI  \
# 0               0                    0               0      126          42
# 9               0                    0               0      126          44
# 1               0                    0               0       86          39
# 2               0                    0               0      101          42
# 3               0                    0               0      101          40
#
#    Days_CO  Days_NO2  Days_Ozone  Days_SO2  Days_PM2_5  Days_PM10
# ...

# %%
# Group each year by State

# %%
grouped_p_2011 = pd.DataFrame({"Days_with_AQI": pollution_2011_states.groupby(["State"]).mean()["Days_with_AQI"], 
                                "Year": pollution_2011_states.groupby(["State"]).mean()["Year"],
                             "Good_Days": pollution_2011_states.groupby(["State"]).mean()["Good_Days"],
                             "Moderate_Days": pollution_2011_states.groupby(["State"]).mean()["Moderate_Days"], 
                             "Unhealthy_Days": pollution_2011_states.groupby(["State"]).mean()["Unhealthy_Days"],   
                             "Very_Unhealthy_Days": pollution_2011_states.groupby(["State"]).mean()["Very_Unhealthy_Days"], 
                             "Hazardous_Days": pollution_2011_states.groupby(["State"]).mean()["Unhealthy_Days"],
                             "Days_CO": pollution_2011_states.groupby(["State"]).mean()["Days_CO"],
                             "Days_NO2": pollution_2011_states.groupby(["State"]).mean()["Days_NO2"],
                             "Days_Ozone": pollution_2011_states.groupby(["State"]).mean()["Days_Ozone"],
                             "Days_SO2": pollution_2011_states.groupby(["State"]).mean()["Days_SO2"],
                             "Days_PM2_5": pollution_2011_states.groupby(["State"]).mean()["Days_PM2_5"],
                             "Days_PM10": pollution_2011_states.groupby(["State"]).mean()["Days_PM10"]})

# %%
grouped_p_2011_i = grouped_p_2011.reset_index()    
grouped_p_2011_i
# Out:
#                    State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0                Alabama     248.526316  2011.0  171.789474      72.368421
# 1                 Alaska     274.500000  2011.0  235.250000      34.875000
# 2                Arizona     320.615385  2011.0  177.153846     117.000000
# 3               Arkansas     216.882353  2011.0  154.470588      59.176471
# 4             California     345.648148  2011.0  193.166667     120.370370
# 5               Colorado     285.156250  2011.0  190.468750      85.406250
# 6            Connecticut     280.875000  2011.0  221.625000      50.750000
# 7      Country Of Mexico     362.500000  2011.0  220.000000     106.500000
# 8               Delaware     365.000000  2011.0  250.000000     102.000000
# 9   District Of Columbia     365.000000  2011.0  135.000000     214.000000
# 10               Florida     347.743590  2011.0  276.000000      67.897436
# ...

# %%
grouped_p_2012 = pd.DataFrame({"Days_with_AQI": pollution_2012_states.groupby(["State"]).mean()["Days_with_AQI"], 
                                "Year": pollution_2012_states.groupby(["State"]).mean()["Year"],
                             "Good_Days": pollution_2012_states.groupby(["State"]).mean()["Good_Days"],
                             "Moderate_Days": pollution_2012_states.groupby(["State"]).mean()["Moderate_Days"], 
                             "Unhealthy_Days": pollution_2012_states.groupby(["State"]).mean()["Unhealthy_Days"],   
                             "Very_Unhealthy_Days": pollution_2012_states.groupby(["State"]).mean()["Very_Unhealthy_Days"], 
                             "Hazardous_Days": pollution_2012_states.groupby(["State"]).mean()["Unhealthy_Days"],
                             "Days_CO": pollution_2012_states.groupby(["State"]).mean()["Days_CO"],
                             "Days_NO2": pollution_2012_states.groupby(["State"]).mean()["Days_NO2"],
                             "Days_Ozone": pollution_2012_states.groupby(["State"]).mean()["Days_Ozone"],
                             "Days_SO2": pollution_2012_states.groupby(["State"]).mean()["Days_SO2"],
                             "Days_PM2_5": pollution_2012_states.groupby(["State"]).mean()["Days_PM2_5"],
                             "Days_PM10": pollution_2012_states.groupby(["State"]).mean()["Days_PM10"]})

# %%
grouped_p_2012_i = grouped_p_2012.reset_index()   
grouped_p_2012_i
# Out:
#                    State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0                Alabama     263.588235  2012.0  201.000000      58.823529
# 1                 Alaska     301.250000  2012.0  258.625000      36.625000
# 2                Arizona     336.538462  2012.0  185.846154     120.076923
# 3               Arkansas     225.071429  2012.0  164.571429      56.500000
# 4             California     349.611111  2012.0  202.314815     113.833333
# 5               Colorado     292.193548  2012.0  198.032258      81.354839
# 6            Connecticut     314.750000  2012.0  222.750000      75.875000
# 7      Country Of Mexico     366.000000  2012.0  271.000000      67.000000
# 8               Delaware     358.000000  2012.0  237.333333     101.000000
# 9   District Of Columbia     366.000000  2012.0  127.000000     211.000000
# 10               Florida     357.410256  2012.0  305.051282      50.410256
# ...

# %%
grouped_p_2013 = pd.DataFrame({"Days_with_AQI": pollution_2013_states.groupby(["State"]).mean()["Days_with_AQI"], 
                                "Year": pollution_2013_states.groupby(["State"]).mean()["Year"],
                             "Good_Days": pollution_2013_states.groupby(["State"]).mean()["Good_Days"],
                             "Moderate_Days": pollution_2013_states.groupby(["State"]).mean()["Moderate_Days"], 
                             "Unhealthy_Days": pollution_2013_states.groupby(["State"]).mean()["Unhealthy_Days"],   
                             "Very_Unhealthy_Days": pollution_2013_states.groupby(["State"]).mean()["Very_Unhealthy_Days"], 
                             "Hazardous_Days": pollution_2013_states.groupby(["State"]).mean()["Unhealthy_Days"],
                             "Days_CO": pollution_2013_states.groupby(["State"]).mean()["Days_CO"],
                             "Days_NO2": pollution_2013_states.groupby(["State"]).mean()["Days_NO2"],
                             "Days_Ozone": pollution_2013_states.groupby(["State"]).mean()["Days_Ozone"],
                             "Days_SO2": pollution_2013_states.groupby(["State"]).mean()["Days_SO2"],
                             "Days_PM2_5": pollution_2013_states.groupby(["State"]).mean()["Days_PM2_5"],
                             "Days_PM10": pollution_2013_states.groupby(["State"]).mean()["Days_PM10"]})

# %%
grouped_p_2013_i = grouped_p_2013.reset_index()  
grouped_p_2013_i
# Out:
#                    State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0                Alabama     265.166667  2013.0  224.888889      40.111111
# 1                 Alaska     284.250000  2013.0  244.000000      31.875000
# 2                Arizona     346.615385  2013.0  208.692308     116.615385
# 3               Arkansas     268.636364  2013.0  215.090909      53.090909
# 4             California     346.185185  2013.0  190.944444     127.148148
# 5               Colorado     304.333333  2013.0  215.833333      80.733333
# 6            Connecticut     315.000000  2013.0  213.375000      91.750000
# 7      Country Of Mexico     363.500000  2013.0  289.500000      45.500000
# 8               Delaware     362.333333  2013.0  264.666667      94.000000
# 9   District Of Columbia     365.000000  2013.0  203.000000     161.000000
# 10               Florida     354.289474  2013.0  311.315789      42.105263
# ...

# %%
grouped_p_2014 = pd.DataFrame({"Days_with_AQI": pollution_2014_states.groupby(["State"]).mean()["Days_with_AQI"], 
                                "Year": pollution_2014_states.groupby(["State"]).mean()["Year"],
                             "Good_Days": pollution_2014_states.groupby(["State"]).mean()["Good_Days"],
                             "Moderate_Days": pollution_2014_states.groupby(["State"]).mean()["Moderate_Days"], 
                             "Unhealthy_Days": pollution_2014_states.groupby(["State"]).mean()["Unhealthy_Days"],   
                             "Very_Unhealthy_Days": pollution_2014_states.groupby(["State"]).mean()["Very_Unhealthy_Days"], 
                             "Hazardous_Days": pollution_2014_states.groupby(["State"]).mean()["Unhealthy_Days"],
                             "Days_CO": pollution_2014_states.groupby(["State"]).mean()["Days_CO"],
                             "Days_NO2": pollution_2014_states.groupby(["State"]).mean()["Days_NO2"],
                             "Days_Ozone": pollution_2014_states.groupby(["State"]).mean()["Days_Ozone"],
                             "Days_SO2": pollution_2014_states.groupby(["State"]).mean()["Days_SO2"],
                             "Days_PM2_5": pollution_2014_states.groupby(["State"]).mean()["Days_PM2_5"],
                             "Days_PM10": pollution_2014_states.groupby(["State"]).mean()["Days_PM10"]})

# %%
grouped_p_2014_i = grouped_p_2014.reset_index()  
grouped_p_2014_i
# Out:
#                    State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0                Alabama     260.444444  2014.0  213.444444      46.111111
# 1                 Alaska     274.125000  2014.0  218.125000      43.625000
# 2                Arizona     357.307692  2014.0  217.076923     115.846154
# 3               Arkansas     272.363636  2014.0  230.272727      41.818182
# 4             California     344.444444  2014.0  193.759259     121.074074
# 5               Colorado     302.233333  2014.0  234.800000      64.300000
# 6            Connecticut     316.125000  2014.0  235.500000      73.625000
# 7      Country Of Mexico     132.500000  2014.0  110.500000      15.500000
# 8               Delaware     364.666667  2014.0  253.666667     106.333333
# 9   District Of Columbia     365.000000  2014.0  225.000000     136.000000
# 10               Florida     357.538462  2014.0  305.461538      50.794872
# ...

# %%
grouped_p_2015 = pd.DataFrame({"Days_with_AQI": pollution_2015_states.groupby(["State"]).mean()["Days_with_AQI"], 
                                "Year": pollution_2015_states.groupby(["State"]).mean()["Year"],
                             "Good_Days": pollution_2015_states.groupby(["State"]).mean()["Good_Days"],
                             "Moderate_Days": pollution_2015_states.groupby(["State"]).mean()["Moderate_Days"], 
                             "Unhealthy_Days": pollution_2015_states.groupby(["State"]).mean()["Unhealthy_Days"],   
                             "Very_Unhealthy_Days": pollution_2015_states.groupby(["State"]).mean()["Very_Unhealthy_Days"], 
                             "Hazardous_Days": pollution_2015_states.groupby(["State"]).mean()["Unhealthy_Days"],
                             "Days_CO": pollution_2015_states.groupby(["State"]).mean()["Days_CO"],
                             "Days_NO2": pollution_2015_states.groupby(["State"]).mean()["Days_NO2"],
                             "Days_Ozone": pollution_2015_states.groupby(["State"]).mean()["Days_Ozone"],
                             "Days_SO2": pollution_2015_states.groupby(["State"]).mean()["Days_SO2"],
                             "Days_PM2_5": pollution_2015_states.groupby(["State"]).mean()["Days_PM2_5"],
                             "Days_PM10": pollution_2015_states.groupby(["State"]).mean()["Days_PM10"]})

# %%
grouped_p_2015_i = grouped_p_2015.reset_index()  
grouped_p_2015_i
# Out:
#                    State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0                Alabama     287.277778  2015.0  217.777778      68.277778
# 1                 Alaska     255.625000  2015.0  205.875000      40.500000
# 2                Arizona     359.230769  2015.0  242.692308      98.538462
# 3               Arkansas     270.636364  2015.0  231.000000      39.454545
# 4             California     344.166667  2015.0  196.388889     121.333333
# 5               Colorado     289.935484  2015.0  225.516129      60.870968
# 6            Connecticut     317.625000  2015.0  234.125000      71.750000
# 7      Country Of Mexico      56.000000  2015.0    8.000000      34.000000
# 8               Delaware     365.000000  2015.0  252.000000     108.666667
# 9   District Of Columbia     365.000000  2015.0  217.000000     143.000000
# 10               Florida     359.641026  2015.0  320.692308      38.384615
# ...

# %%
grouped_p_2011_i
# Out:
#                    State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0                Alabama     248.526316  2011.0  171.789474      72.368421
# 1                 Alaska     274.500000  2011.0  235.250000      34.875000
# 2                Arizona     320.615385  2011.0  177.153846     117.000000
# 3               Arkansas     216.882353  2011.0  154.470588      59.176471
# 4             California     345.648148  2011.0  193.166667     120.370370
# 5               Colorado     285.156250  2011.0  190.468750      85.406250
# 6            Connecticut     280.875000  2011.0  221.625000      50.750000
# 7      Country Of Mexico     362.500000  2011.0  220.000000     106.500000
# 8               Delaware     365.000000  2011.0  250.000000     102.000000
# 9   District Of Columbia     365.000000  2011.0  135.000000     214.000000
# 10               Florida     347.743590  2011.0  276.000000      67.897436
# ...

# %%
# drop Puerto Rico data
grouped_states_pr11 = grouped_p_2011_i.drop(index = 40)
grouped_states_pr12 = grouped_p_2012_i.drop(index = 40)
grouped_states_pr13 = grouped_p_2013_i.drop(index = 40)
grouped_states_pr14 = grouped_p_2014_i.drop(index = 40)
grouped_states_pr15 = grouped_p_2015_i.drop(index = 40)

# %%
grouped_states_pr15.tail(15)
# Out:
#              State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 38          Oregon     345.956522  2015.0  282.652174      56.478261
# 39    Pennsylvania     361.131579  2015.0  248.710526     107.447368
# 41    Rhode Island     361.000000  2015.0  286.333333      69.666667
# 42  South Carolina     295.631579  2015.0  258.210526      37.210526
# 43    South Dakota     338.700000  2015.0  293.900000      43.100000
# 44       Tennessee     264.375000  2015.0  216.166667      46.708333
# 45           Texas     349.853659  2015.0  273.853659      70.048780
# 46            Utah     341.428571  2015.0  250.285714      85.000000
# 47         Vermont     301.750000  2015.0  256.000000      45.000000
# 48  Virgin Islands      73.500000  2015.0   56.500000      17.000000
# 49        Virginia     261.000000  2015.0  228.142857      32.342857
# 50      Washington     345.827586  2015.0  292.758621      48.137931
# 51   West Virginia     280.466667  2015.0  234.066667      45.200000
# ...

# %%
# drop Virgin Islands data
grouped_states_vi11 = grouped_states_pr11.drop(index = 48)
grouped_states_vi12 = grouped_states_pr12.drop(index = 48)
grouped_states_vi13 = grouped_states_pr13.drop(index = 48)
grouped_states_vi14 = grouped_states_pr14.drop(index = 48)
grouped_states_vi15 = grouped_states_pr15.drop(index = 48)
grouped_states_vi15.tail(6)
# Out:
#             State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 47        Vermont     301.750000  2015.0  256.000000      45.000000
# 49       Virginia     261.000000  2015.0  228.142857      32.342857
# 50     Washington     345.827586  2015.0  292.758621      48.137931
# 51  West Virginia     280.466667  2015.0  234.066667      45.200000
# 52      Wisconsin     291.785714  2015.0  245.857143      42.678571
# 53        Wyoming     309.421053  2015.0  262.578947      45.684211
#
#     Unhealthy_Days  Very_Unhealthy_Days  Hazardous_Days   Days_CO   Days_NO2  \
# 47        0.000000             0.000000        0.000000  0.000000  14.750000
# 49        0.000000             0.000000        0.000000  1.142857  35.057143
# 50        1.034483             0.068966        1.034483  0.000000   2.689655
# 51        0.066667             0.000000        0.066667  0.133333   0.000000
# 52        0.071429             0.000000        0.071429  0.000000   0.714286
# ...

# %%
# drop Mexico data
grouped_states_clean_2011 = grouped_states_vi11.drop(index = 7)
grouped_states_clean_2012 = grouped_states_vi12.drop(index = 7)
grouped_states_clean_2013 = grouped_states_vi13.drop(index = 7)
grouped_states_clean_2014 = grouped_states_vi14.drop(index = 7)
grouped_states_clean_2015 = grouped_states_vi15.drop(index = 7)
grouped_states_clean_2015.head(8)
# Out:
#          State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0      Alabama     287.277778  2015.0  217.777778      68.277778
# 1       Alaska     255.625000  2015.0  205.875000      40.500000
# 2      Arizona     359.230769  2015.0  242.692308      98.538462
# 3     Arkansas     270.636364  2015.0  231.000000      39.454545
# 4   California     344.166667  2015.0  196.388889     121.333333
# 5     Colorado     289.935484  2015.0  225.516129      60.870968
# 6  Connecticut     317.625000  2015.0  234.125000      71.750000
# 8     Delaware     365.000000  2015.0  252.000000     108.666667
#
#    Unhealthy_Days  Very_Unhealthy_Days  Hazardous_Days   Days_CO  Days_NO2  \
# 0        0.166667             0.000000        0.166667  0.000000  0.611111
# 1        5.125000             0.375000        5.125000  0.375000  0.375000
# 2        2.461538             0.076923        2.461538  0.000000  2.769231
# 3        0.000000             0.000000        0.000000  0.000000  2.636364
# ...

# %%
# reset indicies
grouped_states_2011_i = grouped_states_clean_2011.reset_index(drop=True)  
grouped_states_2012_i = grouped_states_clean_2012.reset_index(drop=True)  
grouped_states_2013_i = grouped_states_clean_2013.reset_index(drop=True)  
grouped_states_2014_i = grouped_states_clean_2014.reset_index(drop=True)  
grouped_states_2015_i = grouped_states_clean_2015.reset_index(drop=True)

# %%
grouped_states_2014_i.tail()
# Out:
#             State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 46       Virginia     260.771429  2014.0  230.200000      30.228571
# 47     Washington     343.344828  2014.0  300.551724      40.965517
# 48  West Virginia     281.000000  2014.0  233.666667      46.933333
# 49      Wisconsin     294.777778  2014.0  238.037037      52.518519
# 50        Wyoming     310.315789  2014.0  266.105263      43.315789
#
#     Unhealthy_Days  Very_Unhealthy_Days  Hazardous_Days   Days_CO   Days_NO2  \
# 46        0.028571                  0.0        0.028571  5.171429  39.142857
# 47        0.275862                  0.0        0.275862  0.206897   3.172414
# 48        0.000000                  0.0        0.000000  0.133333   0.000000
# 49        0.074074                  0.0        0.074074  0.000000   0.666667
# 50        0.315789                  0.0        0.315789  0.000000   5.105263
#
#     Days_Ozone   Days_SO2  Days_PM2_5  Days_PM10
# ...

# %%
# Stack tables together using concat

pollution_concat_1 = pd.concat([grouped_states_2011_i, grouped_states_2012_i], axis =0)
pollution_concat_2 = pd.concat([pollution_concat_1, grouped_states_2013_i], axis =0)
pollution_concat_3 = pd.concat([pollution_concat_2, grouped_states_2014_i], axis =0)
pollution_all = pd.concat([pollution_concat_3, grouped_states_2015_i], axis =0)
pollution_all
# Out:
#             State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0         Alabama     248.526316  2011.0  171.789474      72.368421
# 1          Alaska     274.500000  2011.0  235.250000      34.875000
# 2         Arizona     320.615385  2011.0  177.153846     117.000000
# 3        Arkansas     216.882353  2011.0  154.470588      59.176471
# 4      California     345.648148  2011.0  193.166667     120.370370
# ..            ...            ...     ...         ...            ...
# 46       Virginia     261.000000  2015.0  228.142857      32.342857
# 47     Washington     345.827586  2015.0  292.758621      48.137931
# 48  West Virginia     280.466667  2015.0  234.066667      45.200000
# 49      Wisconsin     291.785714  2015.0  245.857143      42.678571
# 50        Wyoming     309.421053  2015.0  262.578947      45.684211
#
#     Unhealthy_Days  Very_Unhealthy_Days  Hazardous_Days   Days_CO   Days_NO2  \
# ...

# %%
pollution_all.head(53)
# Out:
#                    State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0                Alabama     248.526316  2011.0  171.789474      72.368421
# 1                 Alaska     274.500000  2011.0  235.250000      34.875000
# 2                Arizona     320.615385  2011.0  177.153846     117.000000
# 3               Arkansas     216.882353  2011.0  154.470588      59.176471
# 4             California     345.648148  2011.0  193.166667     120.370370
# 5               Colorado     285.156250  2011.0  190.468750      85.406250
# 6            Connecticut     280.875000  2011.0  221.625000      50.750000
# 7               Delaware     365.000000  2011.0  250.000000     102.000000
# 8   District Of Columbia     365.000000  2011.0  135.000000     214.000000
# 9                Florida     347.743590  2011.0  276.000000      67.897436
# 10               Georgia     295.625000  2011.0  168.343750     118.781250
# ...

# %%
pollution_stats = pollution_all.reset_index(drop=True)
pollution_stats
# Out:
#              State  Days_with_AQI    Year   Good_Days  Moderate_Days  \
# 0          Alabama     248.526316  2011.0  171.789474      72.368421
# 1           Alaska     274.500000  2011.0  235.250000      34.875000
# 2          Arizona     320.615385  2011.0  177.153846     117.000000
# 3         Arkansas     216.882353  2011.0  154.470588      59.176471
# 4       California     345.648148  2011.0  193.166667     120.370370
# ..             ...            ...     ...         ...            ...
# 250       Virginia     261.000000  2015.0  228.142857      32.342857
# 251     Washington     345.827586  2015.0  292.758621      48.137931
# 252  West Virginia     280.466667  2015.0  234.066667      45.200000
# 253      Wisconsin     291.785714  2015.0  245.857143      42.678571
# 254        Wyoming     309.421053  2015.0  262.578947      45.684211
#
#      Unhealthy_Days  Very_Unhealthy_Days  Hazardous_Days   Days_CO   Days_NO2  \
# ...

# %%
# formatting
pollution_formatted = pollution_stats.round(2)
pollution_formatted["Year"] = pollution_formatted["Year"].astype(float).map("{:.0f}".format)
pollution_formatted
# Out:
#              State  Days_with_AQI  Year  Good_Days  Moderate_Days  \
# 0          Alabama         248.53  2011     171.79          72.37
# 1           Alaska         274.50  2011     235.25          34.88
# 2          Arizona         320.62  2011     177.15         117.00
# 3         Arkansas         216.88  2011     154.47          59.18
# 4       California         345.65  2011     193.17         120.37
# ..             ...            ...   ...        ...            ...
# 250       Virginia         261.00  2015     228.14          32.34
# 251     Washington         345.83  2015     292.76          48.14
# 252  West Virginia         280.47  2015     234.07          45.20
# 253      Wisconsin         291.79  2015     245.86          42.68
# 254        Wyoming         309.42  2015     262.58          45.68
#
#      Unhealthy_Days  Very_Unhealthy_Days  Hazardous_Days  Days_CO  Days_NO2  \
# 0              0.37                 0.00            0.37     0.11      0.00
# ...

# %%
pollution_all = pollution_formatted
pollution_all
# Out:
#              State  Days_with_AQI  Year  Good_Days  Moderate_Days  \
# 0          Alabama         248.53  2011     171.79          72.37
# 1           Alaska         274.50  2011     235.25          34.88
# 2          Arizona         320.62  2011     177.15         117.00
# 3         Arkansas         216.88  2011     154.47          59.18
# 4       California         345.65  2011     193.17         120.37
# ..             ...            ...   ...        ...            ...
# 250       Virginia         261.00  2015     228.14          32.34
# 251     Washington         345.83  2015     292.76          48.14
# 252  West Virginia         280.47  2015     234.07          45.20
# 253      Wisconsin         291.79  2015     245.86          42.68
# 254        Wyoming         309.42  2015     262.58          45.68
#
#      Unhealthy_Days  Very_Unhealthy_Days  Hazardous_Days  Days_CO  Days_NO2  \
# 0              0.37                 0.00            0.37     0.11      0.00
# ...

# %%
# Export to csv

pollution_all.to_csv('..\Resources\Tableau_clean\pollution_all.csv', index=False)
