# %% [markdown]
# ## Data Cleaning - For Tableau Import/Map
#
# ### Import dependcies and read in csv files

# %%
# Import pandas

import pandas as pd

# %%
# Assigning the paths to our CSV files

file = "Resources/Pollution_clean/Clean_Pollution.csv"
file1 = "Resources/Medicare_clean/clean_pc_state_rates_2011.csv"
file2 = "Resources/Medicare_clean/clean_pc_state_rates_2012.csv"
file3 = "Resources/Medicare_clean/clean_pc_state_rates_2013.csv"
file4 = "Resources/Medicare_clean/clean_pc_state_rates_2014.csv"
file5 = "Resources/Medicare_clean/clean_pc_state_rates_2015.csv"
file6 = "Resources/Census_clean/clean_census_2011.csv"
file7 = "Resources/Census_clean/clean_census_2012.csv"
file8 = "Resources/Census_clean/clean_census_2013.csv"
file9 = "Resources/Census_clean/clean_census_2014.csv"
file10 = "Resources/Census_clean/clean_census_2015.csv"
file11 = "Resources/Tableau_clean/states_lat_and_long.csv"

# %%
# Latitude and longitude: from https://developers.google.com/public-data/docs/canonical/states_csv
states = pd.read_csv(file11)
states = states.sort_values("name") 
states.head()
# Out:
#   state   latitude   longitude        name
# 1    AL  32.318231  -86.902298     Alabama
# 0    AK  63.588753 -154.493062      Alaska
# 3    AZ  34.048928 -111.093731     Arizona
# 2    AR  35.201050  -91.831833    Arkansas
# 4    CA  36.778261 -119.417932  California

# %% [markdown]
# ### Medicare Data

# %%
# Read our data into pandas

medicare_2011 = pd.read_csv(file1)
medicare_2012 = pd.read_csv(file2)
medicare_2013 = pd.read_csv(file3)
medicare_2014 = pd.read_csv(file4)
medicare_2015 = pd.read_csv(file5)

# %%
medicare_2011.head()
# Out:
#    state_id  state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 0         1     Alabama                478784                  82.5
# 1         2      Alaska                 49648                  70.9
# 2         3     Arizona                465298                  78.2
# 3         4    Arkansas                327939                  80.7
# 4         5  California               2238140                  72.7
#
#    diabetic_enrollees_age_65_to_75  \
# 0                            69691
# 1                             5449
# 2                            50991
# 3                            40202
# 4                           243999
#
#    average_diabetic_enrollees_hemoglobin_a1c_test  \
# 0                                            83.9
# 1                                            74.5
# 2                                            78.5
# 3                                            82.5
# 4                                            80.6
#
# ...

# %%
# Idenitfy nan values from 2013
medicare_2013.tail()
# Out:
#     state_id state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 52       NaN        NaN                   NaN                   NaN
# 53       NaN        NaN                   NaN                   NaN
# 54       NaN        NaN                   NaN                   NaN
# 55       NaN        NaN                   NaN                   NaN
# 56       NaN        NaN                   NaN                   NaN
#
#     diabetic_enrollees_age_65_to_75  \
# 52                              NaN
# 53                              NaN
# 54                              NaN
# 55                              NaN
# 56                              NaN
#
#     average_diabetic_enrollees_hemoglobin_a1c_test  \
# 52                                             NaN
# 53                                             NaN
# 54                                             NaN
# 55                                             NaN
# 56                                             NaN
#
# ...

# %%
# Drop nan values from 2013
medicare_2013_dropped = medicare_2013.iloc[0:52]
medicare_2013_dropped.tail()
# Out:
#     state_id     state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 47      50.0     Washington              571799.0                  78.9
# 48      51.0  West Virginia              204275.0                  80.9
# 49      52.0      Wisconsin              484902.0                  80.1
# 50      53.0        Wyoming               68066.0                  74.6
# 51      99.0  United States            26755951.0                  79.1
#
#     diabetic_enrollees_age_65_to_75  \
# 47                          61248.0
# 48                          32596.0
# 49                          52893.0
# 50                           6475.0
# 51                        3313579.0
#
#     average_diabetic_enrollees_hemoglobin_a1c_test  \
# 47                                            86.1
# 48                                            83.8
# 49                                            90.0
# 50                                            75.4
# ...

# %%
# Drop extra row tallying up the United States
medicare_2011_states = medicare_2011.iloc[0:51]
medicare_2012_states = medicare_2012.iloc[0:51]
medicare_2013_states = medicare_2013_dropped.iloc[0:51]
medicare_2014_states = medicare_2014.iloc[0:51]
medicare_2015_states = medicare_2015.iloc[0:51]
medicare_2013_states.tail()
# Out:
#     state_id     state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 46      49.0       Virginia              807461.0                  82.7
# 47      50.0     Washington              571799.0                  78.9
# 48      51.0  West Virginia              204275.0                  80.9
# 49      52.0      Wisconsin              484902.0                  80.1
# 50      53.0        Wyoming               68066.0                  74.6
#
#     diabetic_enrollees_age_65_to_75  \
# 46                         107366.0
# 47                          61248.0
# 48                          32596.0
# 49                          52893.0
# 50                           6475.0
#
#     average_diabetic_enrollees_hemoglobin_a1c_test  \
# 46                                            86.6
# 47                                            86.1
# 48                                            83.8
# 49                                            90.0
# ...

# %%
# Sort Medicare dataframes by state name
medicare_2011 = medicare_2011.sort_values("state_name")  
medicare_2012 = medicare_2012.sort_values("state_name")  
medicare_2013 = medicare_2013.sort_values("state_name")  
medicare_2014 = medicare_2014.sort_values("state_name")  
medicare_2015 = medicare_2015.sort_values("state_name")

# %%
# Append latitude and longitude into Medicare dataframes
medicare_2011['latitude'] = states['latitude']
medicare_2011['longitude'] = states['longitude']
medicare_2012['latitude'] = states['latitude']
medicare_2012['longitude'] = states['longitude']
medicare_2013['latitude'] = states['latitude']
medicare_2013['longitude'] = states['longitude']
medicare_2014['latitude'] = states['latitude']
medicare_2014['longitude'] = states['longitude']
medicare_2015['latitude'] = states['latitude']
medicare_2015['longitude'] = states['longitude']

# %%
# Lists for year columns (made in excel using the "&" formula and the fill function)
medicare_year_2011 = ["2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011"]

medicare_year_2012 = ["2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012"]

medicare_year_2013 = ["2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013"]

medicare_year_2014 = ["2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014"]

medicare_year_2015 = ["2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015"]

# %%
# Adding the year column into each dataframe in order to use year filters in Tableau
medicare_2011_states.insert(1, "year", medicare_year_2011, True)
medicare_2012_states.insert(1, "year", medicare_year_2012, True)
medicare_2013_states.insert(1, "year", medicare_year_2013, True)
medicare_2014_states.insert(1, "year", medicare_year_2014, True)
medicare_2015_states.insert(1, "year", medicare_year_2015, True)

# %%
# Stack tables together using concat
medicare_concat_1 = pd.concat([medicare_2011_states, medicare_2012_states], axis =0)
medicare_concat_2 = pd.concat([medicare_concat_1, medicare_2013_states], axis =0)
medicare_concat_3 = pd.concat([medicare_concat_2, medicare_2014_states], axis =0)
medicare_all = pd.concat([medicare_concat_3, medicare_2015_states], axis =0)
medicare_all
# Out:
#     state_id  year     state_name  beneficiaries_part_b  one_ambulatory_visit  \
# 0        1.0  2011        Alabama              478784.0                  82.5
# 1        2.0  2011         Alaska               49648.0                  70.9
# 2        3.0  2011        Arizona              465298.0                  78.2
# 3        4.0  2011       Arkansas              327939.0                  80.7
# 4        5.0  2011     California             2238140.0                  72.7
# ..       ...   ...            ...                   ...                   ...
# 46      49.0  2015       Virginia              832699.0                  83.3
# 47      50.0  2015     Washington              610922.0                  78.5
# 48      51.0  2015  West Virginia              206961.0                  80.8
# 49      52.0  2015      Wisconsin              474364.0                  79.8
# 50      53.0  2015        Wyoming               72959.0                  72.7
#
# ...

# %%
# Export to csv
medicare_all.to_csv('Resources\Tableau_clean\medicare_all.csv', index=False)

# %% [markdown]
# ### Census Data

# %%
# Read our data into pandas
census_2011 = pd.read_csv(file6)
census_2012 = pd.read_csv(file7)
census_2013 = pd.read_csv(file8)
census_2014 = pd.read_csv(file9)
census_2015 = pd.read_csv(file10)

# %%
census_2011
# Out:
#     State                  Name  Population    HHI  PovertyRate
# 0       1               Alabama     4747424  42934    17.133186
# 1       2                Alaska      700703  69014     9.292239
# 2       4               Arizona     6337373  50752    15.835820
# 3       5              Arkansas     2895928  40149    17.846507
# 4       6            California    36969200  61632    14.096818
# 5       8              Colorado     4966061  57685    12.237606
# 6       9           Connecticut     3558172  69243     9.183676
# 7      10              Delaware      890856  59317    10.866515
# 8      11  District of Columbia      593955  61835    17.144902
# 9      12               Florida    18688787  47827    14.336939
# 10     13               Georgia     9600612  49736    16.055872
# 11     15                Hawaii     1346554  67116     9.980068
# 12     16                 Idaho     1549987  46890    13.982956
# 13     17              Illinois    12790182  56576    12.825681
# ...

# %%
# Drop extra row tallying up Puerto Rico
census_2011_states = census_2011.iloc[0:51]
census_2012_states = census_2012.iloc[0:51]
census_2013_states = census_2013.iloc[0:51]
census_2014_states = census_2014.iloc[0:51]
census_2015_states = census_2015.iloc[0:51]
census_2011_states.head()
# Out:
#    State        Name  Population    HHI  PovertyRate
# 0      1     Alabama     4747424  42934    17.133186
# 1      2      Alaska      700703  69014     9.292239
# 2      4     Arizona     6337373  50752    15.835820
# 3      5    Arkansas     2895928  40149    17.846507
# 4      6  California    36969200  61632    14.096818

# %%
# Sort Census dataframes by state name
census_2011 = census_2011.sort_values("Name")  
census_2012 = census_2012.sort_values("Name")  
census_2013 = census_2013.sort_values("Name")  
census_2014 = census_2014.sort_values("Name")  
census_2015 = census_2015.sort_values("Name")

# %%
# Append latitude and longitude into Census dataframes
census_2011['Latitude'] = states['latitude']
census_2011['Longitude'] = states['longitude']
census_2012['Latitude'] = states['latitude']
census_2012['Longitude'] = states['longitude']
census_2013['Latitude'] = states['latitude']
census_2013['Longitude'] = states['longitude']
census_2014['Latitude'] = states['latitude']
census_2014['Longitude'] = states['longitude']
census_2015['Latitude'] = states['latitude']
census_2015['Longitude'] = states['longitude']

# %%
census_2011
# Out:
#     State                  Name  Population    HHI  PovertyRate   Latitude  \
# 0       1               Alabama     4747424  42934    17.133186  63.588753
# 1       2                Alaska      700703  69014     9.292239  32.318231
# 2       4               Arizona     6337373  50752    15.835820  35.201050
# 3       5              Arkansas     2895928  40149    17.846507  34.048928
# 4       6            California    36969200  61632    14.096818  36.778261
# 5       8              Colorado     4966061  57685    12.237606  39.550051
# 6       9           Connecticut     3558172  69243     9.183676  41.603221
# 7      10              Delaware      890856  59317    10.866515  38.905985
# 8      11  District of Columbia      593955  61835    17.144902  38.910832
# 9      12               Florida    18688787  47827    14.336939  27.664827
# 10     13               Georgia     9600612  49736    16.055872  32.157435
# ...

# %%
# Lists for year columns (copied from above)
census_year_2011 = ["2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", 
        "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011", "2011"]

census_year_2012 = ["2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012",
             "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012", "2012"]

census_year_2013 = ["2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013",
             "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013", "2013"]

census_year_2014 = ["2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014",
                      "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014", "2014"]

census_year_2015 = ["2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015",
                      "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015", "2015"]

# %%
# Adding the year column into each dataframe
census_2011_states.insert(1, "year", census_year_2011, True)
census_2012_states.insert(1, "year", census_year_2012, True)
census_2013_states.insert(1, "year", census_year_2013, True)
census_2014_states.insert(1, "year", census_year_2014, True)
census_2015_states.insert(1, "year", census_year_2015, True)

# %%
# Stack tables together using concat
census_concat_1 = pd.concat([census_2011_states, census_2012_states], axis =0)
census_concat_2 = pd.concat([census_concat_1, census_2013_states], axis =0)
census_concat_3 = pd.concat([census_concat_2, census_2014_states], axis =0)
census_all = pd.concat([census_concat_3, census_2015_states], axis =0)
census_all
# Out:
#     State  year           Name  Population    HHI  PovertyRate
# 0       1  2011        Alabama     4747424  42934    17.133186
# 1       2  2011         Alaska      700703  69014     9.292239
# 2       4  2011        Arizona     6337373  50752    15.835820
# 3       5  2011       Arkansas     2895928  40149    17.846507
# 4       6  2011     California    36969200  61632    14.096818
# ..    ...   ...            ...         ...    ...          ...
# 46     51  2015       Virginia     8256630  65015    11.164628
# 47     53  2015     Washington     6985464  61062    13.005750
# 48     54  2015  West Virginia     1851420  41751    17.466809
# 49     55  2015      Wisconsin     5742117  53357    12.614651
# 50     56  2015        Wyoming      579679  58840    11.212240
#
# [255 rows x 6 columns]

# %%
# Export to csv
census_all.to_csv('Resources\Tableau_clean\census_all.csv', index=False)

# %% [markdown]
# ### Pollution Data

# %%
# Read our data into pandas
pollution_dataframe = pd.read_csv(file)
pollution_dataframe.head()
# Out:
#      state    county     city  date_local          no2_units   no2_mean  \
# 0  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 1  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 2  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 3  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 4  Arizona  Maricopa  Phoenix  2000-01-02  Parts per billion  22.958333
#
#             o3_units   o3_mean          so2_units  so2_mean  \
# 0  Parts per million  0.022500  Parts per billion  3.000000
# 1  Parts per million  0.022500  Parts per billion  3.000000
# 2  Parts per million  0.022500  Parts per billion  2.975000
# 3  Parts per million  0.022500  Parts per billion  2.975000
# 4  Parts per million  0.013375  Parts per billion  1.958333
#
#             co_units   co_mean
# 0  Parts per million  1.145833
# 1  Parts per million  0.878947
# 2  Parts per million  1.145833
# 3  Parts per million  0.878947
# ...

# %%
# Check data types
pollution_dataframe.dtypes
# Out:
# state          object
# county         object
# city           object
# date_local     object
# no2_units      object
# no2_mean      float64
# o3_units       object
# o3_mean       float64
# so2_units      object
# so2_mean      float64
# co_units       object
# co_mean       float64
# dtype: object

# %%
# Convert to datetime object
pollution_dataframe['date_local'] =  pd.to_datetime(pollution_dataframe['date_local'])
pollution_dataframe.head()
# Out:
#      state    county     city date_local          no2_units   no2_mean  \
# 0  Arizona  Maricopa  Phoenix 2000-01-01  Parts per billion  19.041667
# 1  Arizona  Maricopa  Phoenix 2000-01-01  Parts per billion  19.041667
# 2  Arizona  Maricopa  Phoenix 2000-01-01  Parts per billion  19.041667
# 3  Arizona  Maricopa  Phoenix 2000-01-01  Parts per billion  19.041667
# 4  Arizona  Maricopa  Phoenix 2000-01-02  Parts per billion  22.958333
#
#             o3_units   o3_mean          so2_units  so2_mean  \
# 0  Parts per million  0.022500  Parts per billion  3.000000
# 1  Parts per million  0.022500  Parts per billion  3.000000
# 2  Parts per million  0.022500  Parts per billion  2.975000
# 3  Parts per million  0.022500  Parts per billion  2.975000
# 4  Parts per million  0.013375  Parts per billion  1.958333
#
#             co_units   co_mean
# 0  Parts per million  1.145833
# 1  Parts per million  0.878947
# 2  Parts per million  1.145833
# 3  Parts per million  0.878947
# ...

# %%
# Confirm conversions
pollution_dataframe.dtypes
# Out:
# state                 object
# county                object
# city                  object
# date_local    datetime64[ns]
# no2_units             object
# no2_mean             float64
# o3_units              object
# o3_mean              float64
# so2_units             object
# so2_mean             float64
# co_units              object
# co_mean              float64
# dtype: object

# %%
# Filter out unneeded dates

pollution_filtered = pollution_dataframe[pollution_dataframe['date_local'] >='2011-01-01']
pollution_filtered
# Out:
#                state     county       city date_local          no2_units  \
# 1072382      Arizona   Maricopa    Phoenix 2011-01-01  Parts per billion
# 1072383      Arizona   Maricopa    Phoenix 2011-01-01  Parts per billion
# 1072384      Arizona   Maricopa    Phoenix 2011-01-01  Parts per billion
# 1072385      Arizona   Maricopa    Phoenix 2011-01-01  Parts per billion
# 1072386      Arizona   Maricopa    Phoenix 2011-01-02  Parts per billion
# ...              ...        ...        ...        ...                ...
# 1249893  Connecticut  New Haven  New Haven 2012-02-08  Parts per billion
# 1249894  Connecticut  New Haven  New Haven 2012-02-08  Parts per billion
# 1249895  Connecticut  New Haven  New Haven 2012-02-08  Parts per billion
# 1249896  Connecticut  New Haven  New Haven 2012-02-09  Parts per billion
# 1249897  Connecticut  New Haven  New Haven 2012-02-09  Parts per billion
#
#           no2_mean           o3_units   o3_mean          so2_units  so2_mean  \
# ...

# %%
# Drop duplicate rows by state
pollution_deduped_states = pollution_filtered.drop_duplicates(subset="state")
pollution_deduped_states.head()
# Out:
#                state     county               city date_local  \
# 1072382      Arizona   Maricopa            Phoenix 2011-01-01
# 1075948     Arkansas    Pulaski  North Little Rock 2011-01-01
# 1081788   California    Alameda            Oakland 2011-01-01
# 1119202     Colorado      Adams              Welby 2011-01-01
# 1120476  Connecticut  Fairfield           Westport 2011-03-31
#
#                  no2_units   no2_mean           o3_units   o3_mean  \
# 1072382  Parts per billion  24.416667  Parts per million  0.014417
# 1075948  Parts per billion   3.329167  Parts per million  0.025375
# 1081788  Parts per billion  12.882609  Parts per million  0.015167
# 1119202  Parts per billion  26.217391  Parts per million  0.015167
# 1120476  Parts per billion  10.875000  Parts per million  0.035000
#
#                  so2_units  so2_mean           co_units   co_mean
# 1072382  Parts per billion  1.708333  Parts per million  0.995833
# ...

# %%
# Reset the index
pollution_reset =  pollution_deduped_states.reset_index(drop=True)
pollution_reset.head()
# Out:
#          state     county               city date_local          no2_units  \
# 0      Arizona   Maricopa            Phoenix 2011-01-01  Parts per billion
# 1     Arkansas    Pulaski  North Little Rock 2011-01-01  Parts per billion
# 2   California    Alameda            Oakland 2011-01-01  Parts per billion
# 3     Colorado      Adams              Welby 2011-01-01  Parts per billion
# 4  Connecticut  Fairfield           Westport 2011-03-31  Parts per billion
#
#     no2_mean           o3_units   o3_mean          so2_units  so2_mean  \
# 0  24.416667  Parts per million  0.014417  Parts per billion  1.708333
# 1   3.329167  Parts per million  0.025375  Parts per billion  1.850000
# 2  12.882609  Parts per million  0.015167  Parts per billion  0.591304
# 3  26.217391  Parts per million  0.015167  Parts per billion  2.565217
# 4  10.875000  Parts per million  0.035000  Parts per billion  0.712500
#
#             co_units   co_mean
# 0  Parts per million  0.995833
# ...

# %%
# Append latitude and longitude into Census dataframes
pollution_reset['latitude'] = states['latitude']
pollution_reset['longitude'] = states['longitude']

# %%
# Filter and export individual csvs by year
pollution_filtered_individual = pollution_reset[pollution_reset['date_local'] >='2011-01-01']
pollution_filtered_2011 = pollution_filtered_individual[pollution_filtered_individual['date_local'] <='2011-12-31']
pollution_filtered_2011.tail()
# Out:
#                 state                 county                city date_local  \
# 32              Texas                 Dallas              Dallas 2011-01-01
# 33               Utah              Salt Lake      Salt Lake City 2011-01-01
# 34           Virginia                Henrico  East Highland Park 2011-03-31
# 35            Wyoming                Laramie       Not in a city 2011-01-01
# 36  Country Of Mexico  BAJA CALIFORNIA NORTE             Tijuana 2011-01-01
#
#             no2_units   no2_mean           o3_units   o3_mean  \
# 32  Parts per billion  11.833333  Parts per million  0.019375
# 33  Parts per billion  30.208333  Parts per million  0.011250
# 34  Parts per billion   4.747826  Parts per million  0.021000
# 35  Parts per billion   0.286957  Parts per million  0.042333
# 36  Parts per billion  10.566667  Parts per million  0.030875
#
#             so2_units  so2_mean           co_units   co_mean   latitude  \
# ...

# %%
# Filter out Mexico data

pollution_2011 = pollution_filtered_2011.iloc[0:36]
pollution_2011
# Out:
#                    state                county                      city  \
# 0                Arizona              Maricopa                   Phoenix
# 1               Arkansas               Pulaski         North Little Rock
# 2             California               Alameda                   Oakland
# 3               Colorado                 Adams                     Welby
# 4            Connecticut             Fairfield                  Westport
# 5               Delaware            New Castle                Wilmington
# 6   District Of Columbia  District of Columbia                Washington
# 7                Florida                Orange               Winter Park
# 8                Georgia                DeKalb             Not in a city
# 9                 Hawaii              Honolulu             Not in a city
# 10                 Idaho                   Ada             Not in a city
# 11              Illinois                  Cook                    Cicero
# ...

# %%
pollution_filtered_individual2 = pollution_reset[pollution_reset['date_local'] >='2012-01-01']
pollution_filtered_2012 = pollution_filtered_individual[pollution_filtered_individual['date_local'] <='2012-12-31']
pollution_filtered_2012.tail()
# Out:
#                 state                 county                city date_local  \
# 32              Texas                 Dallas              Dallas 2011-01-01
# 33               Utah              Salt Lake      Salt Lake City 2011-01-01
# 34           Virginia                Henrico  East Highland Park 2011-03-31
# 35            Wyoming                Laramie       Not in a city 2011-01-01
# 36  Country Of Mexico  BAJA CALIFORNIA NORTE             Tijuana 2011-01-01
#
#             no2_units   no2_mean           o3_units   o3_mean  \
# 32  Parts per billion  11.833333  Parts per million  0.019375
# 33  Parts per billion  30.208333  Parts per million  0.011250
# 34  Parts per billion   4.747826  Parts per million  0.021000
# 35  Parts per billion   0.286957  Parts per million  0.042333
# 36  Parts per billion  10.566667  Parts per million  0.030875
#
#             so2_units  so2_mean           co_units   co_mean   latitude  \
# ...

# %%
pollution_2012 = pollution_filtered_2012.iloc[0:36]
pollution_2012.tail()
# Out:
#            state     county                city date_local          no2_units  \
# 31  South Dakota  Minnehaha         Sioux Falls 2011-01-01  Parts per billion
# 32         Texas     Dallas              Dallas 2011-01-01  Parts per billion
# 33          Utah  Salt Lake      Salt Lake City 2011-01-01  Parts per billion
# 34      Virginia    Henrico  East Highland Park 2011-03-31  Parts per billion
# 35       Wyoming    Laramie       Not in a city 2011-01-01  Parts per billion
#
#      no2_mean           o3_units   o3_mean          so2_units  so2_mean  \
# 31   5.250000  Parts per million  0.039500  Parts per billion  0.562500
# 32  11.833333  Parts per million  0.019375  Parts per billion  0.200000
# 33  30.208333  Parts per million  0.011250  Parts per billion  1.020833
# 34   4.747826  Parts per million  0.021000  Parts per billion  0.104348
# 35   0.286957  Parts per million  0.042333  Parts per billion  0.081818
#
#              co_units   co_mean   latitude   longitude
# ...

# %%
pollution_filtered_individual3 = pollution_reset[pollution_reset['date_local'] >='2013-01-01']
pollution_filtered_2013 = pollution_filtered_individual[pollution_filtered_individual['date_local'] <='2013-12-31']
pollution_filtered_2013.tail()
# Out:
#                 state                 county                city date_local  \
# 32              Texas                 Dallas              Dallas 2011-01-01
# 33               Utah              Salt Lake      Salt Lake City 2011-01-01
# 34           Virginia                Henrico  East Highland Park 2011-03-31
# 35            Wyoming                Laramie       Not in a city 2011-01-01
# 36  Country Of Mexico  BAJA CALIFORNIA NORTE             Tijuana 2011-01-01
#
#             no2_units   no2_mean           o3_units   o3_mean  \
# 32  Parts per billion  11.833333  Parts per million  0.019375
# 33  Parts per billion  30.208333  Parts per million  0.011250
# 34  Parts per billion   4.747826  Parts per million  0.021000
# 35  Parts per billion   0.286957  Parts per million  0.042333
# 36  Parts per billion  10.566667  Parts per million  0.030875
#
#             so2_units  so2_mean           co_units   co_mean   latitude  \
# ...

# %%
pollution_2013 = pollution_filtered_2012.iloc[0:36]
pollution_2013.tail()
# Out:
#            state     county                city date_local          no2_units  \
# 31  South Dakota  Minnehaha         Sioux Falls 2011-01-01  Parts per billion
# 32         Texas     Dallas              Dallas 2011-01-01  Parts per billion
# 33          Utah  Salt Lake      Salt Lake City 2011-01-01  Parts per billion
# 34      Virginia    Henrico  East Highland Park 2011-03-31  Parts per billion
# 35       Wyoming    Laramie       Not in a city 2011-01-01  Parts per billion
#
#      no2_mean           o3_units   o3_mean          so2_units  so2_mean  \
# 31   5.250000  Parts per million  0.039500  Parts per billion  0.562500
# 32  11.833333  Parts per million  0.019375  Parts per billion  0.200000
# 33  30.208333  Parts per million  0.011250  Parts per billion  1.020833
# 34   4.747826  Parts per million  0.021000  Parts per billion  0.104348
# 35   0.286957  Parts per million  0.042333  Parts per billion  0.081818
#
#              co_units   co_mean   latitude   longitude
# ...

# %%
pollution_filtered_individual4 = pollution_reset[pollution_reset['date_local'] >='2014-01-01']
pollution_filtered_2014 = pollution_filtered_individual[pollution_filtered_individual['date_local'] <='2014-12-31']
pollution_filtered_2014.tail()
# Out:
#                 state                 county                city date_local  \
# 32              Texas                 Dallas              Dallas 2011-01-01
# 33               Utah              Salt Lake      Salt Lake City 2011-01-01
# 34           Virginia                Henrico  East Highland Park 2011-03-31
# 35            Wyoming                Laramie       Not in a city 2011-01-01
# 36  Country Of Mexico  BAJA CALIFORNIA NORTE             Tijuana 2011-01-01
#
#             no2_units   no2_mean           o3_units   o3_mean  \
# 32  Parts per billion  11.833333  Parts per million  0.019375
# 33  Parts per billion  30.208333  Parts per million  0.011250
# 34  Parts per billion   4.747826  Parts per million  0.021000
# 35  Parts per billion   0.286957  Parts per million  0.042333
# 36  Parts per billion  10.566667  Parts per million  0.030875
#
#             so2_units  so2_mean           co_units   co_mean   latitude  \
# ...

# %%
pollution_2014 = pollution_filtered_2012.iloc[0:36]
pollution_2014.tail()
# Out:
#            state     county                city date_local          no2_units  \
# 31  South Dakota  Minnehaha         Sioux Falls 2011-01-01  Parts per billion
# 32         Texas     Dallas              Dallas 2011-01-01  Parts per billion
# 33          Utah  Salt Lake      Salt Lake City 2011-01-01  Parts per billion
# 34      Virginia    Henrico  East Highland Park 2011-03-31  Parts per billion
# 35       Wyoming    Laramie       Not in a city 2011-01-01  Parts per billion
#
#      no2_mean           o3_units   o3_mean          so2_units  so2_mean  \
# 31   5.250000  Parts per million  0.039500  Parts per billion  0.562500
# 32  11.833333  Parts per million  0.019375  Parts per billion  0.200000
# 33  30.208333  Parts per million  0.011250  Parts per billion  1.020833
# 34   4.747826  Parts per million  0.021000  Parts per billion  0.104348
# 35   0.286957  Parts per million  0.042333  Parts per billion  0.081818
#
#              co_units   co_mean   latitude   longitude
# ...

# %%
pollution_filtered_individual5 = pollution_reset[pollution_reset['date_local'] >='2015-01-01']
pollution_filtered_2015 = pollution_filtered_individual[pollution_filtered_individual['date_local'] <='2015-12-31']
pollution_filtered_2015.tail()
# Out:
#                 state                 county                city date_local  \
# 32              Texas                 Dallas              Dallas 2011-01-01
# 33               Utah              Salt Lake      Salt Lake City 2011-01-01
# 34           Virginia                Henrico  East Highland Park 2011-03-31
# 35            Wyoming                Laramie       Not in a city 2011-01-01
# 36  Country Of Mexico  BAJA CALIFORNIA NORTE             Tijuana 2011-01-01
#
#             no2_units   no2_mean           o3_units   o3_mean  \
# 32  Parts per billion  11.833333  Parts per million  0.019375
# 33  Parts per billion  30.208333  Parts per million  0.011250
# 34  Parts per billion   4.747826  Parts per million  0.021000
# 35  Parts per billion   0.286957  Parts per million  0.042333
# 36  Parts per billion  10.566667  Parts per million  0.030875
#
#             so2_units  so2_mean           co_units   co_mean   latitude  \
# ...

# %%
pollution_2015 = pollution_filtered_2012.iloc[0:36]
pollution_2015.tail()
# Out:
#            state     county                city date_local          no2_units  \
# 31  South Dakota  Minnehaha         Sioux Falls 2011-01-01  Parts per billion
# 32         Texas     Dallas              Dallas 2011-01-01  Parts per billion
# 33          Utah  Salt Lake      Salt Lake City 2011-01-01  Parts per billion
# 34      Virginia    Henrico  East Highland Park 2011-03-31  Parts per billion
# 35       Wyoming    Laramie       Not in a city 2011-01-01  Parts per billion
#
#      no2_mean           o3_units   o3_mean          so2_units  so2_mean  \
# 31   5.250000  Parts per million  0.039500  Parts per billion  0.562500
# 32  11.833333  Parts per million  0.019375  Parts per billion  0.200000
# 33  30.208333  Parts per million  0.011250  Parts per billion  1.020833
# 34   4.747826  Parts per million  0.021000  Parts per billion  0.104348
# 35   0.286957  Parts per million  0.042333  Parts per billion  0.081818
#
#              co_units   co_mean   latitude   longitude
# ...

# %%
# Export to csv
pollution_reset.to_csv('Resources\Tableau_clean\pollution_reset_filtered.csv', index=False)
pollution_2011.to_csv('Resources\Tableau_clean\pollution_2011.csv', index=False)
pollution_2012.to_csv('Resources\Tableau_clean\pollution_2011.csv', index=False)
pollution_2013.to_csv('Resources\Tableau_clean\pollution_2011.csv', index=False)
pollution_2014.to_csv('Resources\Tableau_clean\pollution_2011.csv', index=False)
pollution_2015.to_csv('Resources\Tableau_clean\pollution_2011.csv', index=False)

# %% [markdown]
# #### other attempts to identify duplicates:

# %%
# Getting the duplicate so2_mean by ID number that shows up for state and so2_mean. 
dupes_so2_mean = pollution_filtered[pollution_filtered.duplicated(['so2_mean', 'state'], keep = 'first')]
# Get all the data for the duplicate so2_mean. 
dupes_so2_mean.head(10)
# Out:
#            state    county     city date_local          no2_units   no2_mean  \
# 1072383  Arizona  Maricopa  Phoenix 2011-01-01  Parts per billion  24.416667
# 1072385  Arizona  Maricopa  Phoenix 2011-01-01  Parts per billion  24.416667
# 1072387  Arizona  Maricopa  Phoenix 2011-01-02  Parts per billion  30.750000
# 1072389  Arizona  Maricopa  Phoenix 2011-01-02  Parts per billion  30.750000
# 1072391  Arizona  Maricopa  Phoenix 2011-01-03  Parts per billion  34.291667
# 1072393  Arizona  Maricopa  Phoenix 2011-01-03  Parts per billion  34.291667
# 1072395  Arizona  Maricopa  Phoenix 2011-01-04  Parts per billion  32.833333
# 1072397  Arizona  Maricopa  Phoenix 2011-01-04  Parts per billion  32.833333
# 1072398  Arizona  Maricopa  Phoenix 2011-01-05  Parts per billion  36.416667
# 1072399  Arizona  Maricopa  Phoenix 2011-01-05  Parts per billion  36.416667
#
#                   o3_units   o3_mean          so2_units  so2_mean  \
# ...

# %%
# Getting the duplicate co_mean by ID number that shows up for state and co_mean. 

dupes_co_mean = pollution_filtered[pollution_filtered.duplicated(['co_mean', 'state'], keep = 'first')]
# Get the first ten rows of data for the duplicate co_mean. 
dupes_co_mean.head(10)
# Out:
#            state    county     city date_local          no2_units   no2_mean  \
# 1072384  Arizona  Maricopa  Phoenix 2011-01-01  Parts per billion  24.416667
# 1072385  Arizona  Maricopa  Phoenix 2011-01-01  Parts per billion  24.416667
# 1072388  Arizona  Maricopa  Phoenix 2011-01-02  Parts per billion  30.750000
# 1072389  Arizona  Maricopa  Phoenix 2011-01-02  Parts per billion  30.750000
# 1072392  Arizona  Maricopa  Phoenix 2011-01-03  Parts per billion  34.291667
# 1072393  Arizona  Maricopa  Phoenix 2011-01-03  Parts per billion  34.291667
# 1072396  Arizona  Maricopa  Phoenix 2011-01-04  Parts per billion  32.833333
# 1072397  Arizona  Maricopa  Phoenix 2011-01-04  Parts per billion  32.833333
# 1072399  Arizona  Maricopa  Phoenix 2011-01-05  Parts per billion  36.416667
# 1072400  Arizona  Maricopa  Phoenix 2011-01-05  Parts per billion  36.416667
#
#                   o3_units   o3_mean          so2_units  so2_mean  \
# ...

# %%
# Drop duplicate rows by so2_mean

pollution_deduped_so2 = pollution_filtered.drop_duplicates(subset="so2_mean")
pollution_deduped_so2.reset_index()
pollution_deduped_so2.head(10)
# Out:
#            state    county     city date_local          no2_units   no2_mean  \
# 1072382  Arizona  Maricopa  Phoenix 2011-01-01  Parts per billion  24.416667
# 1072384  Arizona  Maricopa  Phoenix 2011-01-01  Parts per billion  24.416667
# 1072386  Arizona  Maricopa  Phoenix 2011-01-02  Parts per billion  30.750000
# 1072388  Arizona  Maricopa  Phoenix 2011-01-02  Parts per billion  30.750000
# 1072390  Arizona  Maricopa  Phoenix 2011-01-03  Parts per billion  34.291667
# 1072392  Arizona  Maricopa  Phoenix 2011-01-03  Parts per billion  34.291667
# 1072394  Arizona  Maricopa  Phoenix 2011-01-04  Parts per billion  32.833333
# 1072396  Arizona  Maricopa  Phoenix 2011-01-04  Parts per billion  32.833333
# 1072402  Arizona  Maricopa  Phoenix 2011-01-06  Parts per billion  45.041667
# 1072404  Arizona  Maricopa  Phoenix 2011-01-06  Parts per billion  45.041667
#
#                   o3_units   o3_mean          so2_units  so2_mean  \
# ...

# %%
# Drop duplicate rows by co_mean

pollution_deduped_co = pollution_filtered.drop_duplicates(subset="co_mean")
pollution_deduped_co.reset_index()
pollution_deduped_co
# Out:
#                state     county       city date_local          no2_units  \
# 1072382      Arizona   Maricopa    Phoenix 2011-01-01  Parts per billion
# 1072383      Arizona   Maricopa    Phoenix 2011-01-01  Parts per billion
# 1072386      Arizona   Maricopa    Phoenix 2011-01-02  Parts per billion
# 1072387      Arizona   Maricopa    Phoenix 2011-01-02  Parts per billion
# 1072390      Arizona   Maricopa    Phoenix 2011-01-03  Parts per billion
# ...              ...        ...        ...        ...                ...
# 1249848  Connecticut  New Haven  New Haven 2012-01-28  Parts per billion
# 1249860  Connecticut  New Haven  New Haven 2012-01-31  Parts per billion
# 1249864  Connecticut  New Haven  New Haven 2012-02-01  Parts per billion
# 1249884  Connecticut  New Haven  New Haven 2012-02-06  Parts per billion
# 1249896  Connecticut  New Haven  New Haven 2012-02-09  Parts per billion
#
#           no2_mean           o3_units   o3_mean          so2_units  so2_mean  \
# ...
